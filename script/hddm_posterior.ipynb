# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import os
import logging
import arviz as az

# %%
path_model_infdata = os.path.join('../results/hddm/model_fitted', 'm_v_t_a.nc')
assert os.path.exists(path_model_infdata), f" nc file not found: {path_model_infdata}"
m_infdata = az.from_netcdf(path_model_infdata)

# %%
posterior_dict_a = {}
    # a
    if a_condition in m_infdata.posterior:
        posterior_dict[main_param] = m_infdata.posterior[main_param].stack(sample=("chain", "draw")).values
    elif 

posterior_a[inter] = m_infdata.posterior[a].stack(sample=("chain", "draw")).values
data_posterior = pd.DataFrame(posterior_dict)
path_save_posterior = os.path.join(PATH_MODEL_FIt, f'{model_name}_posterior.csv')
data_posterior.to_csv(path_save_posterior, index=False)

# %%
m_infdata
# Out:
# Inference data with groups:
# 	> posterior
# 	> observed_data

# %%
az.summary(m_infdata, kind = "diagnostics", round_to=4)
# Out:
#              mcse_mean  mcse_sd   ess_bulk   ess_tail   r_hat
# a               0.0008   0.0006  4849.5870  4883.5808  1.0002
# a_std           0.0009   0.0007  2349.8503  3694.8102  1.0004
# a_subj.1117     0.0014   0.0010  2416.1277  3569.1300  1.0014
# a_subj.1118     0.0011   0.0008  2681.8007  3757.5756  1.0016
# a_subj.1120     0.0024   0.0017  1368.5361  2111.5705  1.0031
# ...                ...      ...        ...        ...     ...
# z_subj.1266     0.0004   0.0003  2875.1709  4310.9470  1.0014
# z_subj.1268     0.0004   0.0003  2359.8586  3548.5487  1.0011
# z_subj.1270     0.0006   0.0004  1384.3821  2236.0941  1.0013
# z_subj.1276     0.0004   0.0003  2695.3378  4108.4898  1.0003
# z_subj.1281     0.0004   0.0003  2346.2506  4270.2743  1.0014
#
# [298 rows x 5 columns]

# %%
m_infdata
# Out:
# Inference data with groups:
# 	> posterior
# 	> observed_data
